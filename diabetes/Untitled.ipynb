# %%
import pandas as pd
from numpy import nan

# %%
df=pd.read_csv('diabetes.csv')

# %%
sortedData=df.sort_values(['Outcome'])

# %%
trainNegatif=sortedData[:100]

# %%
testNegatif=sortedData[100:150]

# %%
trainPositif=sortedData[len(df)-100:]#768 -100=668 -> :

# %%
testPositif=sortedData[len(df)-150:len(df)-100]#618 -> 668

# %%
frameTrain=[trainNegatif,trainPositif]

# %%
trainData=pd.concat(frameTrain)

# %%
frameTest=[testNegatif,testPositif]

# %%
testData=pd.concat(frameTest)

# %%
testData.to_csv (r'C:\Users\Lenovo\Desktop\test_data.csv', index = False, header=False)

# %%
trainData.to_csv (r'C:\Users\Lenovo\Desktop\train_data.csv', index = False, header=False)

# %%
sortedData
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 383            1       90             62             18       59  25.1
# 465            0      124             56             13      105  21.8
# 466            0       74             52             10       36  27.8
# 467            0       97             64             36      100  36.8
# 469            6      154             78             41      140  46.1
# 470            1      144             82             40        0  41.3
# 471            0      137             70             38        0  33.2
# 472            0      119             66             27        0  38.8
# 473            7      136             90              0        0  29.9
# 474            4      114             64              0        0  28.9
# 475            0      137             84             27        0  27.3
# 477            7      114             76             17      110  23.8
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df[["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI"]] = df[["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI"]].replace(0, nan)

# %%
print(df.isnull().sum())
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
#dataset.dropna(inplace=True)
df.fillna(df.mean(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sortedData
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 383     1.000000   90.000000      62.000000       18.00000   59.000000  25.1
# 465     4.494673  124.000000      56.000000       13.00000  105.000000  21.8
# 466     4.494673   74.000000      52.000000       10.00000   36.000000  27.8
# 467     4.494673   97.000000      64.000000       36.00000  100.000000  36.8
# 469     6.000000  154.000000      78.000000       41.00000  140.000000  46.1
# 470     1.000000  144.000000      82.000000       40.00000  155.548223  41.3
# 471     4.494673  137.000000      70.000000       38.00000  155.548223  33.2
# 472     4.494673  119.000000      66.000000       27.00000  155.548223  38.8
# 473     7.000000  136.000000      90.000000       29.15342  155.548223  29.9
# 474     4.000000  114.000000      64.000000       29.15342  155.548223  28.9
# 475     4.494673  137.000000      84.000000       27.00000  155.548223  27.3
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...
